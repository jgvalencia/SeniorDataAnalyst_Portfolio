# %% [markdown]
# ## Supervised Learning the	goal	is	to	predict	the	species	of	an	Iris	flower based	on	the	length	and	width	of	its	sepals	and	petals. 0	is	Iris	setosa,	1	is	Iris	versicolor,	2	is	Iris virginica
#
# ### Load Python Libraries

# %%
#importing	the	necessary	libraries	
from	sklearn.datasets	import	load_iris
from	sklearn	import	tree
from	sklearn.metrics	import	accuracy_score
import	numpy	as	np

# %% [markdown]
# ### Load IRIS file from SKY-LEARN

# %%
iris	=	load_iris()

x	=	iris.data	#array	of	the	data
y	=	iris.target	#array	of	labels	(i.e	answers)	of	each	data-entry

#getting	label	names	i.e	the	three	flower	species
y_names	=	iris.target_names

# %% [markdown]
# ### Create a random	index	to	split	the	dataset	into	train	and	test random Option

# %%
#test_ids	=	np.random.permutation(len(x))

#splitting	data	and	labels	into	train	and	test
#keeping	last	10	entries	for	testing,	rest	for	training

#x_train	=	x[test_ids[:-10]]
#x_test	=	x[test_ids[-10:]]

#y_train	=	y[test_ids[:-10]]
#y_test	=	y[test_ids[-10:]]

# %% [markdown]
# ### anotheroption	to	split	the	dataset	into	train	and	test (80% 20%) Option keep same characteristics with "random_state=42"

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42, stratify=y
)

# %% [markdown]
# ### classifying	using decision tree

# %%
#classifying	using	decision	tree
clf	=	tree.DecisionTreeClassifier(random_state=42)
#training	(fitting)	the	classifier	with	the	training	set
clf.fit(X_train, y_train)
#predictions	on	the	test	dataset
pred	=	clf.predict(X_test)

print(pred)	#predicted	labels	i.e	flower	species
print(y_test)	#actual	labels
print(accuracy_score(pred,	y_test)*100)	#prediction	accuracy
# Out:
# [0 2 1 1 0 1 0 0 2 1 2 2 2 1 0 0 0 1 1 2 0 2 1 1 2 2 1 0 2 0]
# [0 2 1 1 0 1 0 0 2 1 2 2 2 1 0 0 0 1 1 2 0 2 1 2 2 1 1 0 2 0]
# 93.33333333333333

# %% [markdown]
# ### The following cell predicts what kind of Iris is the new values using the model generated. 0	is	Iris	setosa,	1	is	Iris	versicolor,	2	is	Iris virginica

# %%
# new flower measurements: [sepal length, sepal width, petal length, petal width]
new_iris = [[1.1, 1.5, 1.4, 1.2]]

prediction = clf.predict(new_iris)[0]

if prediction == 0:
    flower_name = "Iris setosa"
elif prediction == 1:
    flower_name = "Iris versicolor"
elif prediction == 2:
    flower_name = "Iris virginica"
else:
    flower_name = "Unknown"

print("Prediction:", prediction)
print("Flower:", flower_name)
# Out:
# Prediction: 0
# Flower: Iris setosa
